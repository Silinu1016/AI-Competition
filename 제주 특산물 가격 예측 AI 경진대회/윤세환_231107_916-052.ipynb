# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import LabelEncoder
from prophet import Prophet
import re
import copy

import warnings
warnings.filterwarnings(action='ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %%
drive_path = "/content/drive/MyDrive/데이터 경진대회/제주 특산물 가격 예측"
train_data_path = drive_path + "/train.csv"
test_data_path = drive_path + "/test.csv"
sample_submission_path = drive_path + "/sample_submission.csv"

# %%
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)

# %%
train_df["timestamp"] = pd.to_datetime(train_df["timestamp"])

# %%
category_list = train_df["ID"].str.replace(r'_\d{8}$', '', regex=True).unique()

# %%
def handle_data_to_prophet(df) :
  transformed_df = df[["ID", "timestamp", "price(원/kg)"]]
  transformed_df["ID"] = transformed_df["ID"].str.replace(r'_\d{8}$', '', regex=True)
  transformed_df = transformed_df.rename(columns={'timestamp': 'ds', 'price(원/kg)': 'y'})
  return transformed_df.copy()

# %%
prophet_train_data = handle_data_to_prophet(train_df)

# %%
prophet_train_data.tail(5)
# Out:
#            ID         ds      y
# 59392  RD_F_J 2023-02-27  468.0
# 59393  RD_F_J 2023-02-28  531.0
# 59394  RD_F_J 2023-03-01  574.0
# 59395  RD_F_J 2023-03-02  523.0
# 59396  RD_F_J 2023-03-03  529.0

# %%
prophet_map = {}

# %%
for category in category_list :
  current_category_train_x = prophet_train_data[prophet_train_data["ID"] == category].drop(columns=["ID"]).sort_values("ds")
  prophet_map[category] = Prophet().fit(current_category_train_x)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/re07zvh7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/z3978rxy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62492', 'data', 'file=/tmp/tmpyxi6d051/re07zvh7.json', 'init=/tmp/tmpyxi6d051/z3978rxy.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelzk0te129/prophet_model-20231107085118.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/jd_5x48f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/7l4tyxqr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19286', 'data', 'file=/tmp/tmpyxi6d051/jd_5x48f.json', 'init=/tmp/tmpyxi6d051/7l4tyxqr.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_model8lz78oi4/prophet_model-20231107085119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/13dodz1w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/8h6ty4mi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23819', 'data', 'file=/tmp/tmpyxi6d051/13dodz1w.json', 'init=/tmp/tmpyxi6d051/8h6ty4mi.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_model5lvv4wj1/prophet_model-20231107085119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/ux41igpm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/frob1t9r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60863', 'data', 'file=/tmp/tmpyxi6d051/ux41igpm.json', 'init=/tmp/tmpyxi6d051/frob1t9r.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modeloo2fv61m/prophet_model-20231107085119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/i408y71x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/151dt8d4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6812', 'data', 'file=/tmp/tmpyxi6d051/i408y71x.json', 'init=/tmp/tmpyxi6d051/151dt8d4.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelxw_rs91h/prophet_model-20231107085120.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/3rwxyzcp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/4n_54xp7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33496', 'data', 'file=/tmp/tmpyxi6d051/3rwxyzcp.json', 'init=/tmp/tmpyxi6d051/4n_54xp7.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_model6fnc9hjv/prophet_model-20231107085120.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/m1ew9rlj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/c6q2f8y4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46588', 'data', 'file=/tmp/tmpyxi6d051/m1ew9rlj.json', 'init=/tmp/tmpyxi6d051/c6q2f8y4.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelwk7vip0y/prophet_model-20231107085120.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/yj53p8xm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/4tl_ms_1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31421', 'data', 'file=/tmp/tmpyxi6d051/yj53p8xm.json', 'init=/tmp/tmpyxi6d051/4tl_ms_1.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelsfym24et/prophet_model-20231107085121.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/ewho639h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/b81alz21.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91288', 'data', 'file=/tmp/tmpyxi6d051/ewho639h.json', 'init=/tmp/tmpyxi6d051/b81alz21.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelqlaoluf3/prophet_model-20231107085121.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/0ys7vf7t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/67s6l5el.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93285', 'data', 'file=/tmp/tmpyxi6d051/0ys7vf7t.json', 'init=/tmp/tmpyxi6d051/67s6l5el.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_model6z6ozgra/prophet_model-20231107085121.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/r82b1_bz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/xlfgi_sv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9475', 'data', 'file=/tmp/tmpyxi6d051/r82b1_bz.json', 'init=/tmp/tmpyxi6d051/xlfgi_sv.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_
json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelxzzr1u7n/prophet_model-20231107085127.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/eop_bipv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/8doxayxx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17289', 'data', 'file=/tmp/tmpyxi6d051/eop_bipv.json', 'init=/tmp/tmpyxi6d051/8doxayxx.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modeldoa3fgwy/prophet_model-20231107085128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/b29ddz2h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/zo0uzt4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39239', 'data', 'file=/tmp/tmpyxi6d051/b29ddz2h.json', 'init=/tmp/tmpyxi6d051/zo0uzt4o.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modeline3p6dw/prophet_model-20231107085128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/jghgnx1g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/4t0qpqxk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60382', 'data', 'file=/tmp/tmpyxi6d051/jghgnx1g.json', 'init=/tmp/tmpyxi6d051/4t0qpqxk.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelwq8et9ge/prophet_model-20231107085128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/e16xeske.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/fxdep9vn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99670', 'data', 'file=/tmp/tmpyxi6d051/e16xeske.json', 'init=/tmp/tmpyxi6d051/fxdep9vn.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modell5ghcq4h/prophet_model-20231107085129.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/7hwnjd3t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/f0vee62j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61984', 'data', 'file=/tmp/tmpyxi6d051/7hwnjd3t.json', 'init=/tmp/tmpyxi6d051/f0vee62j.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelerltolsb/prophet_model-20231107085129.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/r_dkdezd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/g2vubqpt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30060', 'data', 'file=/tmp/tmpyxi6d051/r_dkdezd.json', 'init=/tmp/tmpyxi6d051/g2vubqpt.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelg40fbjos/prophet_model-20231107085130.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/fd_krfus.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/96kiu7k7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48842', 'data', 'file=/tmp/tmpyxi6d051/fd_krfus.json', 'init=/tmp/tmpyxi6d051/96kiu7k7.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelcq9glm4a/prophet_model-20231107085130.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/0197k706.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/2p76sy2w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53132', 'data', 'file=/tmp/tmpyxi6d051/0197k706.json', 'init=/tmp/tmpyxi6d051/2p76sy2w.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modele468331q/prophet_model-20231107085131.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/bo0cwtp8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/jn8odkfj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22849', 'data', 'file=/tmp/tmpyxi6d051/bo0cwtp8.json', 'init=/tmp/tmpyxi6d051/jn8odkfj.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelbin6yryo/prophet_model-20231107085131.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/wtznqr77.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/4jg967li.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3434', 'data', 'file=/tmp/tmpyxi6d051/wtznqr77.json', 'init=/tmp/tmpyxi6d051/4jg967li.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_modelrp2vmrig/prophet_model-20231107085132.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/ze8v57_2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyxi6d051/0zoai32r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64105', 'data', 'file=/tmp/tmpyxi6d051/ze8v57_2.json', 'init=/tmp/tmpyxi6d051/0zoai32r.json', 'output', 'file=/tmp/tmpyxi6d051/prophet_model45uga1j0/prophet_model-20231107085133.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:51:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:51:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test_df["price(원/kg)"] = 0

# %%
prophet_test_data = handle_data_to_prophet(test_df)

# %%
result_map = {}
for category in category_list :
  current_category_test_x = prophet_test_data[prophet_test_data["ID"] == category].drop(columns=["ID"])
  model = prophet_map[category]
  y = model.predict(current_category_test_x)
  result_map[category] = y["yhat"].values.tolist()

# %%
copy_result_map = copy.deepcopy(result_map)

# %%
def assign_result(row) :
  category = re.sub(r'_\d{8}$', '', row["ID"])
  result = copy_result_map[category]
  return result.pop(0)

# %%
submission = pd.read_csv(sample_submission_path)

# %%
submission.head()
# Out:
#                 ID  answer
# 0  TG_A_J_20230304       0
# 1  TG_A_J_20230305       0
# 2  TG_A_J_20230306       0
# 3  TG_A_J_20230307       0
# 4  TG_A_J_20230308       0

# %%
submission["answer"] = 0

# %%
submission["answer"] = submission.apply(assign_result, axis=1)

# %%
submission.tail()
# Out:
#                    ID      answer
# 1087  RD_F_J_20230327  409.107835
# 1088  RD_F_J_20230328  416.558523
# 1089  RD_F_J_20230329  406.792998
# 1090  RD_F_J_20230330  399.355576
# 1091  RD_F_J_20230331  393.630058

# %%
submission.to_csv(drive_path + "/submission_231107_2.csv", index=False)
