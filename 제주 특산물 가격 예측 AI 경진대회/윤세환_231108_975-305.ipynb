# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import LabelEncoder
from prophet import Prophet
import re
import copy

import warnings
warnings.filterwarnings(action='ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %%
drive_path = "/content/drive/MyDrive/데이터 경진대회/제주 특산물 가격 예측"
train_data_path = drive_path + "/train.csv"
test_data_path = drive_path + "/test.csv"
sample_submission_path = drive_path + "/sample_submission.csv"

# %%
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)

# %%
train_df["timestamp"] = pd.to_datetime(train_df["timestamp"])

# %%
category_list = train_df["ID"].str.replace(r'_\d{8}$', '', regex=True).unique()

# %%
def handle_data_to_prophet(df) :
  transformed_df = df[["ID", "timestamp", "price(원/kg)"]]
  transformed_df["ID"] = transformed_df["ID"].str.replace(r'_\d{8}$', '', regex=True)
  transformed_df = transformed_df.rename(columns={'timestamp': 'ds', 'price(원/kg)': 'y'})
  return transformed_df.copy()

# %%
prophet_train_data = handle_data_to_prophet(train_df)

# %%
prophet_train_data.head(5)
# Out:
#        ID         ds       y
# 0  TG_A_J 2019-01-01     0.0
# 1  TG_A_J 2019-01-02     0.0
# 2  TG_A_J 2019-01-03  1728.0
# 3  TG_A_J 2019-01-04  1408.0
# 4  TG_A_J 2019-01-05  1250.0

# %% [markdown]
# ### Prophet 하이퍼 파라미터 탐색

# %%
search_data = prophet_train_data[prophet_train_data["ID"] == "TG_A_J"].drop(columns=["ID"]).sort_values("ds").copy()

# %%
train_size = int(len(search_data) * 0.8)
search_train_data = search_data[:train_size]
# 만약 0을 제외하고 사용하려면 아래 줄 주석을 해제하세요
# search_train_data = search_train_data[search_train_data["y"] > 0]
search_test_data = search_data[train_size:]

# %%
search_train_data
# Out:
#              ds       y
# 2    2019-01-03  1728.0
# 3    2019-01-04  1408.0
# 4    2019-01-05  1250.0
# 6    2019-01-07  1474.0
# 7    2019-01-08  1326.0
# ...         ...     ...
# 1212 2022-04-27  4915.0
# 1213 2022-04-28  5508.0
# 1214 2022-04-29  5998.0
# 1215 2022-04-30  5415.0
# 1217 2022-05-02  4891.0
#
# [781 rows x 2 columns]

# %%
param_grid = {
    'growth': ['linear'],
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 1, 5, 10],
    'seasonality_prior_scale': [0.01, 0.1, 1, 5, 10],
    'changepoint_range': [0.8, 0.85, 0.9, 0.95],
    'yearly_seasonality': [True, False],
    'weekly_seasonality': [True, False],
    'daily_seasonality': [True, False],
    'holidays_prior_scale': [0.1, 1, 5],
}

# %%
def prophet_grid_search(num_iterations, param_grid, train_data, y):
  results = []

  for _ in range(num_iterations) :
    random_params = {
        key : random.choice(value) for key, value in param_grid.items()
    }

    current_model = Prophet(**random_params)
    current_model.fit(train_data)

    y_size = len(y)

    future = current_model.make_future_dataframe(periods=y_size)
    forecast = current_model.predict(future)
    m_predict = forecast["yhat"].values[-y_size:]

    se = np.square(m_predict - y)
    rmse = np.sqrt(np.mean(se))

    results.append((random_params, rmse))
  return results

# %%
y = search_test_data["y"].values[:]
results = prophet_grid_search(30, param_grid, search_train_data, y)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc
.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/l3ymch4f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51861', 'data', 'file=/tmp/tmpsannuvhc/gy1m7dk9.json', 'init=/tmp/tmpsannuvhc/l3ymch4f.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_model7nx0ftms/prophet_model-20231108091450.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:14:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:14:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/9h9bgu72.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/s_4jt_df.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33423', 'data', 'file=/tmp/tmpsannuvhc/9h9bgu72.json', 'init=/tmp/tmpsannuvhc/s_4jt_df.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelo1p9fn9y/prophet_model-20231108091451.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:14:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:14:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/psu1_8wf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/zer6416m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90970', 'data', 'file=/tmp/tmpsannuvhc/psu1_8wf.json', 'init=/tmp/tmpsannuvhc/zer6416m.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelo1piy8c8/prophet_model-20231108091451.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:14:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:14:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/gesu5yac.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/5f76dc0b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27218', 'data', 'file=/tmp/tmpsannuvhc/gesu5yac.json', 'init=/tmp/tmpsannuvhc/5f76dc0b.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelvqp2ldso/prophet_model-20231108091452.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:14:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:14:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/e7str6l_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/mn_qkj4e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37385', 'data', 'file=/tmp/tmpsannuvhc/e7str6l_.json', 'init=/tmp/tmpsannuvhc/mn_qkj4e.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelp2k5bk5n/prophet_model-20231108091453.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:14:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:14:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
sorted_results = sorted(results, key=lambda x : x[1])

# %%
sorted_results[:5]
# Out:
# [({'growth': 'linear',
#    'changepoint_prior_scale': 5,
#    'seasonality_prior_scale': 5,
#    'changepoint_range': 0.8,
#    'yearly_seasonality': True,
#    'weekly_seasonality': True,
#    'daily_seasonality': True,
#    'holidays_prior_scale': 5},
#   2891.5523557453103),
#  ({'growth': 'linear',
#    'changepoint_prior_scale': 5,
#    'seasonality_prior_scale': 0.1,
#    'changepoint_range': 0.85,
#    'yearly_seasonality': True,
#    'weekly_seasonality': True,
#    'daily_seasonality': False,
#    'holidays_prior_scale': 0.1},
#   2989.3289018390233),
#  ({'growth': 'linear',
#    'changepoint_prior_scale': 5,
#    'seasonality_prior_scale': 1,
#    'changepoint_range': 0.8,
#    'yearly_seasonality': True,
#    'weekly_seasonality': False,
#    'daily_seasonality': False,
#    'holidays_prior_scale': 5},
#   3032.868415119233),
#  ({'growth': 'linear',
#    'changepoint_prior_scale': 0.1,
#    'seasonality_prior_scale': 1,
#    'changepoint_range': 0.95,
#    'yearly_seasonality': False,
#    'weekly_seasonality': True,
#    'daily_seasonality': True,
#    'holidays_prior_scale': 1},
#   3105.6389493822685),
#  ({'growth': 'linear',
#    'changepoint_prior_scale': 0.01,
#    'seasonality_prior_scale': 0.1,
#    'changepoint_range': 0.9,
#    'yearly_seasonality': True,
#    'weekly_seasonality': True,
#    'daily_seasonality': True,
#    'holidays_prior_scale': 5},
#   3238.224767120702)]

# %%
best_params, best_rmse = min(results, key=lambda x: x[1])

# %%
best_params, best_rmse
# Out:
# ({'growth': 'linear',
#   'changepoint_prior_scale': 5,
#   'seasonality_prior_scale': 5,
#   'changepoint_range': 0.8,
#   'yearly_seasonality': True,
#   'weekly_seasonality': True,
#   'daily_seasonality': True,
#   'holidays_prior_scale': 5},
#  2891.5523557453103)

# %%
test_model = Prophet(**best_params)
test_model.fit(search_train_data)
future = test_model.make_future_dataframe(periods=305)
forecast = test_model.predict(future)
test_model.plot(forecast)

# %%
prophet_map = {}

# %%
for category in category_list :
  main_model = Prophet(
      **best_params
  )
  current_category_train_x = prophet_train_data[prophet_train_data["ID"] == category].drop(columns=["ID"]).sort_values("ds")
  prophet_map[category] = main_model.fit(current_category_train_x)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/qklmx162.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/1pbi5gf_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77545', 'data', 'file=/tmp/tmpsannuvhc/qklmx162.json', 'init=/tmp/tmpsannuvhc/1pbi5gf_.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelxlbxo0ls/prophet_model-20231108090014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/g_pydrcx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/qowf_48h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2671', 'data', 'file=/tmp/tmpsannuvhc/g_pydrcx.json', 'init=/tmp/tmpsannuvhc/qowf_48h.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_model713j0ie8/prophet_model-20231108090014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/_q7uvthr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/cr3dhqje.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92208', 'data', 'file=/tmp/tmpsannuvhc/_q7uvthr.json', 'init=/tmp/tmpsannuvhc/cr3dhqje.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelgikgus0f/prophet_model-20231108090015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/v1lsg2k3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/uk1oztsd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47677', 'data', 'file=/tmp/tmpsannuvhc/v1lsg2k3.json', 'init=/tmp/tmpsannuvhc/uk1oztsd.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_model4tpnjatl/prophet_model-20231108090015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/c4tsqen_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/30e02krl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2811', 'data', 'file=/tmp/tmpsannuvhc/c4tsqen_.json', 'init=/tmp/tmpsannuvhc/30e02krl.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelc5nnev4z/prophet_model-20231108090016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/qcvylqt9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/j2egy_fi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29141', 'data', 'file=/tmp/tmpsannuvhc/qcvylqt9.json', 'init=/tmp/tmpsannuvhc/j2egy_fi.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelfbe912hf/prophet_model-20231108090017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/3ea1hyok.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/6q3wwdrq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59173', 'data', 'file=/tmp/tmpsannuvhc/3ea1hyok.json', 'init=/tmp/tmpsannuvhc/6q3wwdrq.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_model485h38ma/prophet_model-20231108090017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/4x64tnfy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/hqi_xqvb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21609', 'data', 'file=/tmp/tmpsannuvhc/4x64tnfy.json', 'init=/tmp/tmpsannuvhc/hqi_xqvb.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelwznh27t1/prophet_model-20231108090017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/60fgzm3u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/4xyxaxlo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2964', 'data', 'file=/tmp/tmpsannuvhc/60fgzm3u.json', 'init=/tmp/tmpsannuvhc/4xyxaxlo.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelerfx6ze1/prophet_model-20231108090018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/qcx0u9oq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/vju17t2s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=415', 'data', 'file=/tmp/tmpsannuvhc/qcx0u9oq.json', 'init=/tmp/tmpsannuvhc/vju17t2s.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelw7pdshke/prophet_model-20231108090018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/lqxvovmz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/ecl0w4_c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59008', 'data', 'file=/tmp/tmpsannuvhc/lqxvovmz.json', 'init=/tmp/tmpsannuvhc/ecl0w4_c.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_modelhs5w88jn/prophet_model-20231108090018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:00:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:00:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/ynqmrci9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsannuvhc/u5abun1q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60066', 'data', 'file=/tmp/tmpsannuvhc/ynqmrci9.json', 'init=/tmp/tmpsannuvhc/u5abun1q.json', 'output', 'file=/tmp/tmpsannuvhc/prophet_mod
29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test_df["price(원/kg)"] = 0

# %%
prophet_test_data = handle_data_to_prophet(test_df)

# %%
result_map = {}
for category in category_list :
  current_category_test_x = prophet_test_data[prophet_test_data["ID"] == category].drop(columns=["ID"])
  model = prophet_map[category]
  y = model.predict(current_category_test_x)
  result_map[category] = y["yhat"].values.tolist()

# %%
copy_result_map = copy.deepcopy(result_map)

# %%
def assign_result(row) :
  category = re.sub(r'_\d{8}$', '', row["ID"])
  result = copy_result_map[category]
  return result.pop(0)

# %%
submission = pd.read_csv(sample_submission_path)

# %%
submission.head()
# Out:
#                 ID  answer
# 0  TG_A_J_20230304       0
# 1  TG_A_J_20230305       0
# 2  TG_A_J_20230306       0
# 3  TG_A_J_20230307       0
# 4  TG_A_J_20230308       0

# %%
submission["answer"] = 0

# %%
submission["answer"] = submission.apply(assign_result, axis=1)

# %%
submission.tail()
# Out:
#                    ID      answer
# 1087  RD_F_J_20230327  365.668322
# 1088  RD_F_J_20230328  371.967115
# 1089  RD_F_J_20230329  363.941160
# 1090  RD_F_J_20230330  357.875728
# 1091  RD_F_J_20230331  353.250750

# %%
submission[submission["answer"] < 0]
# Out:
#                   ID     answer
# 400  CR_D_S_20230312  -0.470456
# 403  CR_D_S_20230315  -3.445713
# 405  CR_D_S_20230317  -1.136784
# 406  CR_D_S_20230318  -6.061351
# 407  CR_D_S_20230319  -6.800384
# 408  CR_D_S_20230320  -0.002742
# 409  CR_D_S_20230321  -1.122018
# 410  CR_D_S_20230322  -8.599626
# 412  CR_D_S_20230324  -4.994692
# 413  CR_D_S_20230325  -9.190615
# 414  CR_D_S_20230326  -9.181637
# 415  CR_D_S_20230327  -1.641834
# 416  CR_D_S_20230328  -2.048625
# 417  CR_D_S_20230329  -8.865150
# 419  CR_D_S_20230331  -4.165027
# 448  CR_E_S_20230304 -14.668876
# 449  CR_E_S_20230305 -33.821296
# 450  CR_E_S_20230306 -11.930612
# 451  CR_E_S_20230307 -23.207116
# 452  CR_E_S_20230308  -2.099926
# 453  CR_E_S_20230309 -10.827463
# 454  CR_E_S_20230310 -11.321160
# 455  CR_E_S_20230311 -10.794196
# 456  CR_E_S_20230312 -30.339349
# 457  CR_E_S_20230313  -9.060833
# 458  CR_E_S_20230314 -21.143691
# 459  CR_E_S_20230315  -1.006796
# 460  CR_E_S_20230316 -10.834219
# 461  CR_E_S_20230317 -12.519944
# 462  CR_E_S_20230318 -13.237676
# 463  CR_E_S_20230319 -34.039831
# 464  CR_E_S_20230320 -13.990512
# 465  CR_E_S_20230321 -27.236033
# 466  CR_E_S_20230322  -8.159000
# 467  CR_E_S_20230323 -18.910678
# 468  CR_E_S_20230324 -21.356598
# 469  CR_E_S_20230325 -22.647126
# 470  CR_E_S_20230326 -43.817060
# 471  CR_E_S_20230327 -23.919038
# 472  CR_E_S_20230328 -37.094328
# 473  CR_E_S_20230329 -17.726971
# 474  CR_E_S_20230330 -27.976039
# 475  CR_E_S_20230331 -29.720943

# %%
submission.to_csv(drive_path + "/submission_231108_1.csv", index=False)
