# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)
# 0              0.0
# 1              0.0
# 2           1728.0
# 3           1408.0
# 4           1250.0
# ...            ...
# 59392        468.0
# 59393        531.0
# 59394        574.0
# 59395        523.0
# 59396        529.0
#
# [59397 rows x 7 columns]

# %%
test_df
# Out:
#                    ID   timestamp item corporation location
# 0     TG_A_J_20230304  2023-03-04   TG           A        J
# 1     TG_A_J_20230305  2023-03-05   TG           A        J
# 2     TG_A_J_20230306  2023-03-06   TG           A        J
# 3     TG_A_J_20230307  2023-03-07   TG           A        J
# 4     TG_A_J_20230308  2023-03-08   TG           A        J
# ...               ...         ...  ...         ...      ...
# 1087  RD_F_J_20230327  2023-03-27   RD           F        J
# 1088  RD_F_J_20230328  2023-03-28   RD           F        J
# 1089  RD_F_J_20230329  2023-03-29   RD           F        J
# 1090  RD_F_J_20230330  2023-03-30   RD           F        J
# 1091  RD_F_J_20230331  2023-03-31   RD           F        J
#
# [1092 rows x 5 columns]

# %% [markdown]
# ## Data Pre-Processing

# %%
import holidays
import pandas as pd

def add_weekday(df) :
    df['date'] = pd.to_datetime(df['timestamp'])
    df['weekcode'] = df['date'].dt.weekday

    year_min = df['date'].dt.date.unique().min().year
    year_max = df['date'].dt.date.unique().max().year
    kor_holidays = list(holidays.KOR(years=range(year_min, year_max)).keys())
    idx_kor_holidays = pd.to_datetime(kor_holidays)

    df_temp = df[['date', 'weekcode']].copy()
    df_temp.set_index('date', inplace=True)
    #공휴일은 10으로 표시
    df_temp.loc[idx_kor_holidays, 'weekcode'] = 10
    df_temp.reset_index(inplace=True)

    df['weekcode'] = df_temp['weekcode']

    return df

# %%
train_df = add_weekday(train_df)
test_df = add_weekday(test_df)

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)       date  weekcode
# 0              0.0 2019-01-01        10
# 1              0.0 2019-01-02         2
# 2           1728.0 2019-01-03         3
# 3           1408.0 2019-01-04         4
# 4           1250.0 2019-01-05         5
# ...            ...        ...       ...
# 59392        468.0 2023-02-27         0
# 59393        531.0 2023-02-28         1
# 59394        574.0 2023-03-01         2
# 59395        523.0 2023-03-02         3
# 59396        529.0 2023-03-03         4
#
# [59397 rows x 9 columns]

# %%
def split_time_stamp(train_df, test_df):
    #시계열 특성을 학습에 반영하기 위해 timestamp를 월, 일, 시간으로 나눕니다
    train_df['year'] = train_df['timestamp'].apply(lambda x : int(x[0:4]))
    train_df['month'] = train_df['timestamp'].apply(lambda x : int(x[5:7]))
    train_df['day'] = train_df['timestamp'].apply(lambda x : int(x[8:10]))

    test_df['year'] = test_df['timestamp'].apply(lambda x : int(x[0:4]))
    test_df['month'] = test_df['timestamp'].apply(lambda x : int(x[5:7]))
    test_df['day'] = test_df['timestamp'].apply(lambda x : int(x[8:10]))

    return train_df, test_df

# %%
train_df, test_df = split_time_stamp(train_df, test_df)

test_df
# Out:
#                    ID   timestamp item corporation location       date  \
# 0     TG_A_J_20230304  2023-03-04   TG           A        J 2023-03-04
# 1     TG_A_J_20230305  2023-03-05   TG           A        J 2023-03-05
# 2     TG_A_J_20230306  2023-03-06   TG           A        J 2023-03-06
# 3     TG_A_J_20230307  2023-03-07   TG           A        J 2023-03-07
# 4     TG_A_J_20230308  2023-03-08   TG           A        J 2023-03-08
# ...               ...         ...  ...         ...      ...        ...
# 1087  RD_F_J_20230327  2023-03-27   RD           F        J 2023-03-27
# 1088  RD_F_J_20230328  2023-03-28   RD           F        J 2023-03-28
# 1089  RD_F_J_20230329  2023-03-29   RD           F        J 2023-03-29
# 1090  RD_F_J_20230330  2023-03-30   RD           F        J 2023-03-30
# 1091  RD_F_J_20230331  2023-03-31   RD           F        J 2023-03-31
#
#       weekcode  year  month  day
# 0            5  2023      3    4
# 1            6  2023      3    5
# 2            0  2023      3    6
# 3            1  2023      3    7
# 4            2  2023      3    8
# ...        ...   ...    ...  ...
# 1087         0  2023      3   27
# 1088         1  2023      3   28
# 1089         2  2023      3   29
# 1090         3  2023      3   30
# 1091         4  2023      3   31
#
# [1092 rows x 10 columns]

# %%
#학습에 사용하지 않을 변수들을 제거합니다
train_df_mod = train_df.drop(columns=['ID', 'timestamp', 'supply(kg)', 'date'])
test_x = test_df.drop(columns=['ID', 'timestamp', 'date'])

# %%
from sklearn.model_selection import train_test_split

train_set, val_set = train_test_split(train_df_mod, test_size=0.2, random_state=42)

# %%
train_x = train_set.drop(columns='price(원/kg)')
train_y = train_set['price(원/kg)']

val_x = val_set.drop(columns='price(원/kg)')
val_y = val_set['price(원/kg)']

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corporation', 'location']

for i in qual_col:
    le = LabelEncoder()
    train_x[i]=le.fit_transform(train_x[i])
    val_x[i]=le.transform(val_x[i])
    test_x[i]=le.transform(test_x[i]) #test 데이터에 대해서 fit하는 것은 data leakage에 해당합니다

print('Done.')
# Out:
# Done.

# %%
train_x
# Out:
#        item  corporation  location  weekcode  year  month  day
# 3607      4            1         0         2  2020      7   15
# 28882     1            0         1         6  2023      1    8
# 40072     3            4         0         6  2020      4   19
# 29223     1            3         0         0  2019     10   14
# 50088     0            2         0         2  2022      9   14
# ...     ...          ...       ...       ...   ...    ...  ...
# 54343     0            4         0         3  2021     11    4
# 38158     3            3         1         0  2019      3   25
# 860       4            0         0         0  2021      5   10
# 15795     2            0         0         6  2020      7   19
# 56422     1            5         0         2  2019      3   13
#
# [47517 rows x 7 columns]

# %% [markdown]
# ## Regression Model Fit

# %%
from xgboost import XGBRegressor

xgb_reg = XGBRegressor(n_estimators=50, learning_rate=0.1, max_depth=10, random_state = 42, min_child_weight=5)
xgb_reg.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=50, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %% [markdown]
# # 모델 학습

# %%
from sklearn.metrics import mean_squared_error

val_xgb_predict = xgb_reg.predict(val_x)
mse_xgb = mean_squared_error(val_xgb_predict, val_y)
rmse_xgb = np.sqrt(mse_xgb)
rmse_xgb
# Out:
# 854.8602879991154

# %%
param_xgb = {"max_depth": [10,15, 20, 30,50],
              "n_estimators": [200,300,500,1000],
              "learning_rate": [0.01, 0.05, 0.1, 0.3, 0.5],
              "n_estimators":[50,100,200,300,500,1000],
              'min_child_weight':[1,3,5]
              }

# %%
from sklearn.model_selection import GridSearchCV

gscv_xgb = GridSearchCV (estimator = xgb_reg, param_grid = param_xgb, scoring ='neg_mean_squared_error', cv = 3, refit=True, n_jobs=1, verbose=2)

gscv_xgb.fit(train_x, train_y)
# Out:
# Fitting 3 folds for each of 450 candidates, totalling 1350 fits
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   5.3s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=200; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=200; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=200; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=300; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=300; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=300; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=500; total time=  13.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=500; total time=  13.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=500; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  30.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  28.1s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  28.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=200; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=200; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=200; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=300; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=300; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=300; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=500; total time=   9.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=500; total time=   9.0s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=500; total time=   9.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=200; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=300; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=300; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=300; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=500; total time=   7.4s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=500; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=500; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  15.6s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  15.2s
# [CV] END learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  15.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=300; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=300; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=300; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=500; total time=  20.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=500; total time=  19.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=500; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000; total time=  53.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000; total time=  54.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000; total time=  55.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=200; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=200; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=200; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=300; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=300; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=300; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=500; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=500; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=500; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  36.2s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  36.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  36.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=300; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=300; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=300; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=500; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=500; total time=  10.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=500; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  25.7s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  24.8s
# [CV] END learning_rate=0.01, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=200; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=200; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=200; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=300; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=300; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=300; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=500; total time=  24.5s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=500; total time=  24.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=500; total time=  24.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=300; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=300; total time=   8.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=300; total time=   8.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=500; total time=  18.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=500; total time=  19.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=500; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  47.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  45.9s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  45.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=200; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=200; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=300; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=300; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=300; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=500; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=500; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=500; total time=  12.5s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  31.6s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  30.8s
# [CV] END learning_rate=0.01, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  30.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=200; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=200; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=200; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=300; total time=   9.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=300; total time=   9.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=300; total time=   9.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=500; total time=  23.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=500; total time=  23.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=500; total time=  25.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=1000; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=1000; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=300; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=300; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=300; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=500; total time=  18.1s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=500; total time=  18.1s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=500; total time=  18.4s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  47.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  47.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  47.4s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=50; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=50; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=200; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=200; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=200; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=300; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=300; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=300; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=500; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=500; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=500; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  32.0s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  32.2s
# [CV] END learning_rate=0.01, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  31.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   6.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   6.4s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=1000; total time=   6.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=200; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=300; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=500; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=500; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=500; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=1000; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=500; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=1000; total time=   5.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=100; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=100; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=100; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=200; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=200; total time=   6.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=200; total time=   6.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=300; total time=  11.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=300; total time=  11.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=300; total time=  11.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=500; total time=  22.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=500; total time=  22.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=500; total time=  23.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  48.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  50.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=1, n_estimators=1000; total time=  49.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=200; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=300; total time=   7.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=300; total time=   6.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=300; total time=   7.4s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=500; total time=  13.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=500; total time=  13.2s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=500; total time=  13.0s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  30.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  29.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=3, n_estimators=1000; total time=  29.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=200; total time=   3.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=200; total time=   3.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=200; total time=   3.7s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=300; total time=   5.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=300; total time=   5.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=300; total time=   5.6s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500; total time=   9.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500; total time=   9.3s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500; total time=   9.5s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  21.1s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  20.8s
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=1000; total time=  20.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=100; total time=   5.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=100; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=100; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=200; total time=  13.6s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=200; total time=  13.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=200; total time=  13.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=300; total time=  23.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=300; total time=  24.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=300; total time=  24.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=500; total time=  44.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=500; total time=  45.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=500; total time=  44.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000; total time= 1.0min
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000; total time=  59.6s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=100; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=100; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200; total time=   9.0s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200; total time=   8.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200; total time=   8.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=300; total time=  13.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=300; total time=  13.6s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=300; total time=  13.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=500; total time=  22.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=500; total time=  23.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=500; total time=  24.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  46.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  49.6s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  49.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=100; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=100; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=100; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=200; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=200; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=200; total time=   6.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=300; total time=   9.4s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=300; total time=   9.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=300; total time=   9.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=500; total time=  15.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=500; total time=  16.5s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=500; total time=  16.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  34.1s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  34.9s
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  32.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=100; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=100; total time=   5.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=100; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=200; total time=  14.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=200; total time=  15.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=200; total time=  14.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=300; total time=  25.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=300; total time=  25.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=300; total time=  26.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=500; total time=  46.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=500; total time=  46.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=500; total time=  46.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=1, n_estimators=1000; total time= 1.0min
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=100; total time=   4.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=200; total time=  10.6s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=200; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=200; total time=  10.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=300; total time=  17.2s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=300; total time=  17.5s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=300; total time=  16.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=500; total time=  29.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=500; total time=  29.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=500; total time=  29.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1000; total time= 1.0min
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  59.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=3, n_estimators=1000; total time= 1.1min
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=100; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=100; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=100; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=200; total time=   7.0s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=200; total time=   6.9s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=200; total time=   7.3s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=300; total time=  11.7s
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=5, n_estimators=300; total time=  11.5s
# ...
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=1, n_estimators=1000; total time=   5.8s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=1, n_estimators=1000; total time=   5.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=1, n_estimators=1000; total time=   5.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=50; total time=   2.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=50; total time=   2.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=50; total time=   2.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=100; total time=   5.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=100; total time=   5.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=100; total time=   5.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=200; total time=  10.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=200; total time=  10.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=200; total time=  10.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=300; total time=  10.4s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=300; total time=   8.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=300; total time=   9.3s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=500; total time=   9.4s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=500; total time=   9.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=500; total time=   9.3s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  11.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  11.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1000; total time=  11.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=100; total time=   4.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=100; total time=   3.8s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=200; total time=   7.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=200; total time=   7.9s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=200; total time=   7.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=300; total time=  11.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=300; total time=  11.8s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=300; total time=  11.3s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=500; total time=  15.7s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=500; total time=  15.2s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=500; total time=  15.6s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  19.0s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  15.5s
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1000; total time=  14.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=50; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=50; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=50; total time=   4.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=100; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=100; total time=   4.2s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=100; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=200; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=200; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=300; total time=   4.2s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=300; total time=   4.3s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=300; total time=   4.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=500; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=500; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=500; total time=   4.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=1000; total time=   5.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=1000; total time=   5.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=1, n_estimators=1000; total time=   5.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=50; total time=   3.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=50; total time=   3.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=50; total time=   3.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=100; total time=   7.2s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=100; total time=   7.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=100; total time=   7.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=200; total time=  11.6s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=200; total time=  11.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=200; total time=  11.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=300; total time=  12.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=300; total time=  12.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=300; total time=  12.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=500; total time=  12.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=500; total time=  12.2s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=500; total time=  12.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  10.3s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  10.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=3, n_estimators=1000; total time=  11.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=100; total time=   3.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=200; total time=   9.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300; total time=  13.7s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300; total time=  13.8s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=300; total time=  14.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=500; total time=  17.5s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=500; total time=  16.4s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=500; total time=  15.1s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  16.9s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  14.0s
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=1000; total time=  18.5s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=50; total time=   4.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=50; total time=   4.7s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=50; total time=   4.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=100; total time=   4.7s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=100; total time=   4.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=100; total time=   4.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=200; total time=   4.9s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=200; total time=   4.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=200; total time=   4.9s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=300; total time=   4.9s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=300; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=300; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=500; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=500; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=500; total time=   5.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=1000; total time=   5.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=1000; total time=   5.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=1, n_estimators=1000; total time=   5.3s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=50; total time=   3.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=50; total time=   3.3s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=50; total time=   3.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=100; total time=   7.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=100; total time=   7.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=100; total time=   6.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=200; total time=  10.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=200; total time=   9.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=200; total time=   9.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=300; total time=  10.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=300; total time=   9.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=300; total time=  10.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=500; total time=  10.0s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=500; total time=   9.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=500; total time=  11.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  12.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  12.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=3, n_estimators=1000; total time=  13.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=50; total time=   2.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=50; total time=   2.2s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=50; total time=   2.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=100; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=100; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=100; total time=   4.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=300; total time=  13.5s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=300; total time=  13.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=300; total time=  13.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=500; total time=  17.1s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=500; total time=  16.8s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=500; total time=  14.6s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  15.5s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  15.4s
# [CV] END learning_rate=0.5, max_depth=50, min_child_weight=5, n_estimators=1000; total time=  16.3s
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=0.5, ma...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=300,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=42, ...),
#              n_jobs=1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
#                          'max_depth': [10, 15, 20, 30, 50],
#                          'min_child_weight': [1, 3, 5],
#                          'n_estimators': [50, 100, 200, 300, 500, 1000]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
print('XGB 파라미터: ', gscv_xgb.best_params_)
print('XGB 예측 정확도: {:.4f}'.format(gscv_xgb.best_score_))
# Out:
# XGB 파라미터:  {'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50}
# XGB 예측 정확도: -757007.3744

# %%
np.sqrt(-gscv_xgb.best_score_)
# Out:
# 870.0617072618718

# %% [markdown]
# ## Inference

# %%
preds = xgb_reg.predict(test_x)

# %%
# 예측값중에 음수가 있어서 적용
preds_mask = preds<=100
preds_mask
# Out:
# array([False,  True, False, ..., False, False, False])

# %%
preds[preds_mask]=0

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('./sample_submission.csv')
submission
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
submission['answer'] = preds

# %%
submission.to_csv('./xgb_submission_231109.csv', index=False)
