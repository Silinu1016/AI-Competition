# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')

# %%
import io
train_df = pd.read_csv(io.BytesIO(uploaded['train.csv']))
test_df = pd.read_csv(io.BytesIO(uploaded['test.csv']))
# 데이터 세트는 Pandas Dataframe에 이제 저장됩니다.

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)
# 0              0.0
# 1              0.0
# 2           1728.0
# 3           1408.0
# 4           1250.0
# ...            ...
# 59392        468.0
# 59393        531.0
# 59394        574.0
# 59395        523.0
# 59396        529.0
#
# [59397 rows x 7 columns]

# %%
test_df
# Out:
#                    ID   timestamp item corporation location
# 0     TG_A_J_20230304  2023-03-04   TG           A        J
# 1     TG_A_J_20230305  2023-03-05   TG           A        J
# 2     TG_A_J_20230306  2023-03-06   TG           A        J
# 3     TG_A_J_20230307  2023-03-07   TG           A        J
# 4     TG_A_J_20230308  2023-03-08   TG           A        J
# ...               ...         ...  ...         ...      ...
# 1087  RD_F_J_20230327  2023-03-27   RD           F        J
# 1088  RD_F_J_20230328  2023-03-28   RD           F        J
# 1089  RD_F_J_20230329  2023-03-29   RD           F        J
# 1090  RD_F_J_20230330  2023-03-30   RD           F        J
# 1091  RD_F_J_20230331  2023-03-31   RD           F        J
#
# [1092 rows x 5 columns]

# %% [markdown]
# ## Data Pre-Processing

# %%
import holidays
import pandas as pd

def add_weekday(df) :
    df['date'] = pd.to_datetime(df['timestamp'])
    df['weekcode'] = df['date'].dt.weekday

    year_min = df['date'].dt.date.unique().min().year
    year_max = df['date'].dt.date.unique().max().year
    kor_holidays = list(holidays.KOR(years=range(year_min, year_max)).keys())
    idx_kor_holidays = pd.to_datetime(kor_holidays)

    df_temp = df[['date', 'weekcode']].copy()
    df_temp.set_index('date', inplace=True)
    #공휴일은 10으로 표시
    df_temp.loc[idx_kor_holidays, 'weekcode'] = 10
    df_temp.reset_index(inplace=True)

    df['weekcode'] = df_temp['weekcode']

    return df

# %%
train_df = add_weekday(train_df)
test_df = add_weekday(test_df)

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)       date  weekcode
# 0              0.0 2019-01-01        10
# 1              0.0 2019-01-02         2
# 2           1728.0 2019-01-03         3
# 3           1408.0 2019-01-04         4
# 4           1250.0 2019-01-05         5
# ...            ...        ...       ...
# 59392        468.0 2023-02-27         0
# 59393        531.0 2023-02-28         1
# 59394        574.0 2023-03-01         2
# 59395        523.0 2023-03-02         3
# 59396        529.0 2023-03-03         4
#
# [59397 rows x 9 columns]

# %%
def split_time_stamp(train_df, test_df):
    #시계열 특성을 학습에 반영하기 위해 timestamp를 월, 일, 시간으로 나눕니다
    train_df['year'] = train_df['timestamp'].apply(lambda x : int(x[0:4]))
    train_df['month'] = train_df['timestamp'].apply(lambda x : int(x[5:7]))
    train_df['day'] = train_df['timestamp'].apply(lambda x : int(x[8:10]))

    test_df['year'] = test_df['timestamp'].apply(lambda x : int(x[0:4]))
    test_df['month'] = test_df['timestamp'].apply(lambda x : int(x[5:7]))
    test_df['day'] = test_df['timestamp'].apply(lambda x : int(x[8:10]))

    return train_df, test_df

# %%
train_df, test_df = split_time_stamp(train_df, test_df)

test_df
# Out:
#                    ID   timestamp item corporation location       date  \
# 0     TG_A_J_20230304  2023-03-04   TG           A        J 2023-03-04
# 1     TG_A_J_20230305  2023-03-05   TG           A        J 2023-03-05
# 2     TG_A_J_20230306  2023-03-06   TG           A        J 2023-03-06
# 3     TG_A_J_20230307  2023-03-07   TG           A        J 2023-03-07
# 4     TG_A_J_20230308  2023-03-08   TG           A        J 2023-03-08
# ...               ...         ...  ...         ...      ...        ...
# 1087  RD_F_J_20230327  2023-03-27   RD           F        J 2023-03-27
# 1088  RD_F_J_20230328  2023-03-28   RD           F        J 2023-03-28
# 1089  RD_F_J_20230329  2023-03-29   RD           F        J 2023-03-29
# 1090  RD_F_J_20230330  2023-03-30   RD           F        J 2023-03-30
# 1091  RD_F_J_20230331  2023-03-31   RD           F        J 2023-03-31
#
#       weekcode  year  month  day
# 0            5  2023      3    4
# 1            6  2023      3    5
# 2            0  2023      3    6
# 3            1  2023      3    7
# 4            2  2023      3    8
# ...        ...   ...    ...  ...
# 1087         0  2023      3   27
# 1088         1  2023      3   28
# 1089         2  2023      3   29
# 1090         3  2023      3   30
# 1091         4  2023      3   31
#
# [1092 rows x 10 columns]

# %%
#학습에 사용하지 않을 변수들을 제거합니다
train_df_mod = train_df.drop(columns=['ID', 'timestamp', 'supply(kg)', 'date'])
test_x = test_df.drop(columns=['ID', 'timestamp', 'date'])

# %%
from sklearn.model_selection import train_test_split

train_set, val_set = train_test_split(train_df_mod, test_size=0.2, random_state=42)

# %%
train_x = train_set.drop(columns='price(원/kg)')
train_y = train_set['price(원/kg)']

val_x = val_set.drop(columns='price(원/kg)')
val_y = val_set['price(원/kg)']

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corporation', 'location']

for i in qual_col:
    le = LabelEncoder()
    train_x[i]=le.fit_transform(train_x[i])
    val_x[i]=le.transform(val_x[i])
    test_x[i]=le.transform(test_x[i]) #test 데이터에 대해서 fit하는 것은 data leakage에 해당합니다

print('Done.')
# Out:
# Done.

# %%
train_x
# Out:
#        item  corporation  location  weekcode  year  month  day
# 3607      4            1         0         2  2020      7   15
# 28882     1            0         1         6  2023      1    8
# 40072     3            4         0         6  2020      4   19
# 29223     1            3         0         0  2019     10   14
# 50088     0            2         0         2  2022      9   14
# ...     ...          ...       ...       ...   ...    ...  ...
# 54343     0            4         0         3  2021     11    4
# 38158     3            3         1         0  2019      3   25
# 860       4            0         0         0  2021      5   10
# 15795     2            0         0         6  2020      7   19
# 56422     1            5         0         2  2019      3   13
#
# [47517 rows x 7 columns]

# %% [markdown]
# ## Regression Model Fit

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

ada_reg = AdaBoostRegressor(
 DecisionTreeRegressor(max_depth=15), n_estimators=100,
 loss="square", learning_rate=0.01, random_state=42)
ada_reg.fit(train_x, train_y)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=15),
#                   learning_rate=0.01, loss='square', n_estimators=100,
#                   random_state=42)

# %%
param_ada = {"base_estimator__max_depth": [15, 20, 30, 50],
              "learning_rate": [0.01, 0.05, 0.1, 0.3, 0.5],
              "n_estimators":[50,100,200,300,500],
              }

# %%
from sklearn.model_selection import GridSearchCV

gscv_ada = GridSearchCV (estimator = ada_reg, param_grid = param_ada, scoring ='neg_mean_squared_error', cv = 3, refit=True, n_jobs=1, verbose=2)

gscv_ada.fit(train_x, train_y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=50; total time=   3.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=50; total time=   3.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=100; total time=   6.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=100; total time=   7.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=100; total time=   6.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=200; total time=  13.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=200; total time=  14.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=200; total time=  14.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=300; total time=  20.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=300; total time=  21.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=300; total time=  21.0s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=500; total time=  34.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=500; total time=  34.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.01, n_estimators=500; total time=  34.6s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=50; total time=   3.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=100; total time=   7.1s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=100; total time=   6.6s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=100; total time=   7.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=200; total time=  13.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=200; total time=  13.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=200; total time=  13.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=300; total time=  20.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=300; total time=  19.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=300; total time=  20.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=500; total time=  32.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=500; total time=  32.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.05, n_estimators=500; total time=  33.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=50; total time=   3.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=50; total time=   3.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=100; total time=   6.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=100; total time=   7.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=100; total time=   6.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=200; total time=  13.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=200; total time=  13.6s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=200; total time=  13.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=300; total time=  18.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=300; total time=  19.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=300; total time=  19.1s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=500; total time=  30.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=500; total time=  30.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.1, n_estimators=500; total time=  30.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=50; total time=   3.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=100; total time=   6.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=100; total time=   6.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=100; total time=   6.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=200; total time=  11.9s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=200; total time=  12.1s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=200; total time=  12.0s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=300; total time=  17.0s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=300; total time=  18.1s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=300; total time=  17.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=500; total time=  27.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=500; total time=  29.0s
# [CV] END base_estimator__max_depth=15, learning_rate=0.3, n_estimators=500; total time=  27.8s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=50; total time=   3.0s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=50; total time=   3.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=50; total time=   3.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=100; total time=   5.6s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=100; total time=   6.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=100; total time=   5.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=200; total time=  11.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=200; total time=  11.6s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=200; total time=  11.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=300; total time=  16.5s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=300; total time=  17.4s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=300; total time=  16.3s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=500; total time=  27.2s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=500; total time=  27.7s
# [CV] END base_estimator__max_depth=15, learning_rate=0.5, n_estimators=500; total time=  27.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=50; total time=   4.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=100; total time=   6.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=200; total time=  15.2s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=300; total time=  22.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=300; total time=  22.0s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=500; total time=  37.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=500; total time=  36.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.01, n_estimators=500; total time=  37.2s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=50; total time=   4.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=100; total time=   7.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=100; total time=   7.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=100; total time=   7.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=200; total time=  14.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=200; total time=  15.2s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=200; total time=  15.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=300; total time=  22.2s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=300; total time=  22.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=300; total time=  22.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=500; total time=  37.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=500; total time=  37.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.05, n_estimators=500; total time=  37.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=50; total time=   4.0s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=50; total time=   3.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=100; total time=   7.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=200; total time=  15.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=300; total time=  22.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=300; total time=  22.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=300; total time=  22.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=500; total time=  38.0s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=500; total time=  38.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.1, n_estimators=500; total time=  39.0s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=50; total time=   4.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=50; total time=   3.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=50; total time=   3.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=100; total time=   8.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=100; total time=   8.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=100; total time=   7.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=200; total time=  15.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=200; total time=  16.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=200; total time=  15.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=300; total time=  23.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=300; total time=  23.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=300; total time=  23.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=500; total time=  38.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=500; total time=  38.1s
# [CV] END base_estimator__max_depth=20, learning_rate=0.3, n_estimators=500; total time=  37.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=50; total time=   4.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=100; total time=   6.9s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=100; total time=   7.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=200; total time=  14.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=200; total time=  14.4s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=200; total time=  14.7s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=300; total time=  21.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=300; total time=  21.3s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=300; total time=  21.6s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=500; total time=  35.5s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=500; total time=  35.8s
# [CV] END base_estimator__max_depth=20, learning_rate=0.5, n_estimators=500; total time=  35.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=50; total time=   3.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=50; total time=   4.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=200; total time=  14.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=500; total time=  37.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=500; total time=  37.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.01, n_estimators=500; total time=  37.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=50; total time=   4.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=100; total time=   7.9s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=100; total time=   7.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=200; total time=  15.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=300; total time=  22.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=300; total time=  22.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=300; total time=  23.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=500; total time=  38.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=500; total time=  38.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.05, n_estimators=500; total time=  38.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=50; total time=   4.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=50; total time=   3.6s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=100; total time=   7.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=100; total time=   7.9s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=200; total time=  15.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=200; total time=  15.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=200; total time=  15.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=300; total time=  22.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=300; total time=  23.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=300; total time=  23.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=500; total time=  38.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=500; total time=  38.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.1, n_estimators=500; total time=  38.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=50; total time=   3.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=50; total time=   4.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=50; total time=   3.6s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=100; total time=   7.1s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=200; total time=  14.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=200; total time=  15.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=300; total time=  22.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=300; total time=  22.6s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=500; total time=  37.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=500; total time=  37.6s
# [CV] END base_estimator__max_depth=30, learning_rate=0.3, n_estimators=500; total time=  37.6s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=50; total time=   4.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=200; total time=  14.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=200; total time=  14.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=200; total time=  14.4s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=300; total time=  21.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=300; total time=  21.9s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=300; total time=  21.8s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=500; total time=  35.2s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=500; total time=  35.5s
# [CV] END base_estimator__max_depth=30, learning_rate=0.5, n_estimators=500; total time=  36.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=50; total time=   4.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=50; total time=   3.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=100; total time=   7.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=100; total time=   7.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=200; total time=  14.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=200; total time=  15.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=300; total time=  22.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=300; total time=  22.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=500; total time=  37.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=500; total time=  38.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.01, n_estimators=500; total time=  38.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=50; total time=   4.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=100; total time=   7.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=100; total time=   7.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=100; total time=   7.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=200; total time=  15.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=200; total time=  15.4s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=200; total time=  15.4s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=300; total time=  23.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=300; total time=  22.4s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=300; total time=  22.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=500; total time=  38.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=500; total time=  38.4s
# [CV] END base_estimator__max_depth=50, learning_rate=0.05, n_estimators=500; total time=  39.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=50; total time=   4.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=100; total time=   7.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=100; total time=   7.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=200; total time=  15.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=200; total time=  15.2s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=200; total time=  15.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=300; total time=  22.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=300; total time=  23.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=500; total time=  38.2s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=500; total time=  38.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.1, n_estimators=500; total time=  38.4s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=50; total time=   3.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=50; total time=   4.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=100; total time=   7.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=100; total time=   7.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=200; total time=  15.2s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=200; total time=  15.1s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=200; total time=  15.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=300; total time=  22.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=300; total time=  22.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=500; total time=  37.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=500; total time=  37.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.3, n_estimators=500; total time=  37.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=50; total time=   3.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=50; total time=   4.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=50; total time=   3.9s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=100; total time=   6.8s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=100; total time=   7.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=100; total time=   7.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=200; total time=  14.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=200; total time=  14.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=200; total time=  14.3s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=300; total time=  21.6s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=300; total time=  21.5s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=300; total time=  21.2s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=500; total time=  36.0s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=500; total time=  37.7s
# [CV] END base_estimator__max_depth=50, learning_rate=0.5, n_estimators=500; total time=  35.7s
# GridSearchCV(cv=3,
#              estimator=AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=15),
#                                          learning_rate=0.5, loss='square',
#                                          n_estimators=100, random_state=42),
#              n_jobs=1,
#              param_grid={'base_estimator__max_depth': [15, 20, 30, 50],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
#                          'n_estimators': [50, 100, 200, 300, 500]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
print('ADAB 파라미터: ', gscv_ada.best_params_)
print('ADAB 예측 정확도: {:.4f}'.format(gscv_ada.best_score_))
# Out:
# ADAB 파라미터:  {'base_estimator__max_depth': 15, 'learning_rate': 0.01, 'n_estimators': 100}
# ADAB 예측 정확도: -832504.6540

# %%
np.sqrt(-gscv_ada.best_score_)
# Out:
# 912.416929906908

# %%
from sklearn.metrics import mean_squared_error

val_ada_predict = ada_reg.predict(val_x)
mse_ada = mean_squared_error(val_ada_predict, val_y)
rmse_ada = np.sqrt(mse_ada)
rmse_ada
# Out:
# 875.5444757956384

# %% [markdown]
# ## Inference

# %%
preds = ada_reg.predict(test_x)

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('./sample_submission.csv')
submission
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
submission['answer'] = preds
submission
# Out:
#                    ID       answer
# 0     TG_A_J_20230304  3743.000000
# 1     TG_A_J_20230305     0.000000
# 2     TG_A_J_20230306  3530.666667
# 3     TG_A_J_20230307  3542.000000
# 4     TG_A_J_20230308  3518.200000
# ...               ...          ...
# 1087  RD_F_J_20230327   486.333333
# 1088  RD_F_J_20230328   487.142857
# 1089  RD_F_J_20230329   468.000000
# 1090  RD_F_J_20230330   431.666667
# 1091  RD_F_J_20230331   449.000000
#
# [1092 rows x 2 columns]

# %%
submission.to_csv('./baseline_submission.csv', index=False)
