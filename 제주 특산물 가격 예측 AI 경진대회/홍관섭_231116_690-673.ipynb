# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)
# 0              0.0
# 1              0.0
# 2           1728.0
# 3           1408.0
# 4           1250.0
# ...            ...
# 59392        468.0
# 59393        531.0
# 59394        574.0
# 59395        523.0
# 59396        529.0
#
# [59397 rows x 7 columns]

# %%
test_df
# Out:
#                    ID   timestamp item corporation location
# 0     TG_A_J_20230304  2023-03-04   TG           A        J
# 1     TG_A_J_20230305  2023-03-05   TG           A        J
# 2     TG_A_J_20230306  2023-03-06   TG           A        J
# 3     TG_A_J_20230307  2023-03-07   TG           A        J
# 4     TG_A_J_20230308  2023-03-08   TG           A        J
# ...               ...         ...  ...         ...      ...
# 1087  RD_F_J_20230327  2023-03-27   RD           F        J
# 1088  RD_F_J_20230328  2023-03-28   RD           F        J
# 1089  RD_F_J_20230329  2023-03-29   RD           F        J
# 1090  RD_F_J_20230330  2023-03-30   RD           F        J
# 1091  RD_F_J_20230331  2023-03-31   RD           F        J
#
# [1092 rows x 5 columns]

# %% [markdown]
# ## Data Pre-Processing

# %%
import holidays
import pandas as pd

def add_weekday(df) :
    df['date'] = pd.to_datetime(df['timestamp'])
    df['weekcode'] = df['date'].dt.weekday

    year_min = df['date'].dt.date.unique().min().year
    year_max = df['date'].dt.date.unique().max().year
    kor_holidays = list(holidays.KOR(years=range(year_min, year_max)).keys())
    idx_kor_holidays = pd.to_datetime(kor_holidays)

    df_temp = df[['date', 'weekcode']].copy()
    df_temp.set_index('date', inplace=True)
    #공휴일은 10으로 표시
    df_temp.loc[idx_kor_holidays, 'weekcode'] = 10
    df_temp.reset_index(inplace=True)

    df['weekcode'] = df_temp['weekcode']

    return df

# %%
train_df = add_weekday(train_df)
test_df = add_weekday(test_df)

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)       date  weekcode
# 0              0.0 2019-01-01        10
# 1              0.0 2019-01-02         2
# 2           1728.0 2019-01-03         3
# 3           1408.0 2019-01-04         4
# 4           1250.0 2019-01-05         5
# ...            ...        ...       ...
# 59392        468.0 2023-02-27         0
# 59393        531.0 2023-02-28         1
# 59394        574.0 2023-03-01         2
# 59395        523.0 2023-03-02         3
# 59396        529.0 2023-03-03         4
#
# [59397 rows x 9 columns]

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)       date  weekcode
# 0              0.0 2019-01-01        10
# 1              0.0 2019-01-02         2
# 2           1728.0 2019-01-03         3
# 3           1408.0 2019-01-04         4
# 4           1250.0 2019-01-05         5
# ...            ...        ...       ...
# 59392        468.0 2023-02-27         0
# 59393        531.0 2023-02-28         1
# 59394        574.0 2023-03-01         2
# 59395        523.0 2023-03-02         3
# 59396        529.0 2023-03-03         4
#
# [59397 rows x 9 columns]

# %%
#학습에 사용하지 않을 변수들을 제거합니다
train_df_mod = train_df.drop(columns=['supply(kg)', 'date'])

# %%
train_df_mod
# Out:
#                     ID   timestamp item corporation location  price(원/kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J          0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J          0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J       1728.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J       1408.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J       1250.0
# ...                ...         ...  ...         ...      ...          ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J        468.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J        531.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J        574.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J        523.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J        529.0
#
#        weekcode
# 0            10
# 1             2
# 2             3
# 3             4
# 4             5
# ...         ...
# 59392         0
# 59393         1
# 59394         2
# 59395         3
# 59396         4
#
# [59397 rows x 7 columns]

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corporation', 'location']

for i in qual_col:
    le = LabelEncoder()
    train_df_mod[i]=le.fit_transform(train_df_mod[i])
    test_df[i]=le.transform(test_df[i]) #test 데이터에 대해서 fit하는 것은 data leakage에 해당합니다

print('Done.')
# Out:
# Done.

# %%
test_df
# Out:
#                    ID   timestamp  item  corporation  location       date  \
# 0     TG_A_J_20230304  2023-03-04     4            0         0 2023-03-04
# 1     TG_A_J_20230305  2023-03-05     4            0         0 2023-03-05
# 2     TG_A_J_20230306  2023-03-06     4            0         0 2023-03-06
# 3     TG_A_J_20230307  2023-03-07     4            0         0 2023-03-07
# 4     TG_A_J_20230308  2023-03-08     4            0         0 2023-03-08
# ...               ...         ...   ...          ...       ...        ...
# 1087  RD_F_J_20230327  2023-03-27     3            5         0 2023-03-27
# 1088  RD_F_J_20230328  2023-03-28     3            5         0 2023-03-28
# 1089  RD_F_J_20230329  2023-03-29     3            5         0 2023-03-29
# 1090  RD_F_J_20230330  2023-03-30     3            5         0 2023-03-30
# 1091  RD_F_J_20230331  2023-03-31     3            5         0 2023-03-31
#
#       weekcode
# 0            5
# 1            6
# 2            0
# 3            1
# 4            2
# ...        ...
# 1087         0
# 1088         1
# 1089         2
# 1090         3
# 1091         4
#
# [1092 rows x 7 columns]

# %% [markdown]
# ## Regression Model Fit

# %%
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor

# %%
train_df_mod['item_id']=train_df_mod.ID.str[0:6]

# %%
train_data = TimeSeriesDataFrame(train_df_mod.drop(columns=['ID']))

# %%
predictor = TimeSeriesPredictor( 
    prediction_length=28,
    target="price(원/kg)",
    eval_metric="RMSE",
)

predictor.fit(train_data, random_seed=42)
# Out:
# ================ TimeSeriesPredictor ================
# TimeSeriesPredictor.fit() called
# Fitting with arguments:
# {'enable_ensemble': True,
#  'evaluation_metric': 'RMSE',
#  'excluded_model_types': None,
#  'hyperparameter_tune_kwargs': None,
#  'hyperparameters': 'default',
#  'num_val_windows': 1,
#  'prediction_length': 28,
#  'random_seed': 42,
#  'target': 'price(원/kg)',
#  'time_limit': None,
#  'verbosity': 2}
# Provided training data set with 59397 rows, 39 items (item = single time series). Average time series length is 1523.0. Data frequency is 'D'.
# =====================================================
# Global seed set to 42
# AutoGluon will save models to AutogluonModels\ag-20231116_142025\
# AutoGluon will gauge predictive performance using evaluation metric: 'RMSE'
# 	This metric's sign has been flipped to adhere to being 'higher is better'. The reported score can be multiplied by -1 to get the metric value.
#
# Provided dataset contains following columns:
# 	target:           'price(원/kg)'
# 	past covariates:  ['item', 'corporation', 'location', 'weekcode']
#
# Starting training. Start time is 2023-11-16 23:20:26
# Models that will be trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR']
# Training timeseries model Naive.
# 	-997.0634     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	7.75    s     = Validation (prediction) runtime
# Training timeseries model SeasonalNaive.
# 	-843.9258     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	0.04    s     = Validation (prediction) runtime
# Training timeseries model Theta.
# 	-838.8347     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	22.89   s     = Validation (prediction) runtime
# Training timeseries model AutoETS.
# 	-797.0592     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	9.27    s     = Validation (prediction) runtime
# Training timeseries model RecursiveTabular.
# 	-810.2125     = Validation score (-RMSE)
# 	2.25    s     = Training runtime
# 	0.90    s     = Validation (prediction) runtime
# Training timeseries model DeepAR.
# 	-747.7722     = Validation score (-RMSE)
# 	365.63  s     = Training runtime
# 	1.03    s     = Validation (prediction) runtime
# Fitting simple weighted ensemble.
# 	-718.8461     = Validation score (-RMSE)
# 	1.23    s     = Training runtime
# 	32.57   s     = Validation (prediction) runtime
# Training complete. Models trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR', 'WeightedEnsemble']
# Total runtime: 411.47 s
# Best model: WeightedEnsemble
# Best model score: -718.8461

# %% [markdown]
# ## 모델 학습

# %%
preds = predictor.predict(train_data, random_seed=42)
# Out:
# Global seed set to 42
# Model not specified in predict, will default to the model with the best validation score: WeightedEnsemble

# %% [markdown]
# ## Inference

# %%
preds
# Out:
#                            mean          0.1          0.2          0.3  \
# item_id timestamp
# TG_A_J  2023-03-04  3305.099072  1585.863805  2236.841469  2663.834687
#         2023-03-05   543.990556 -1285.068602  -656.704042  -204.257119
#         2023-03-06  3253.064348   379.547692  1392.910740  2044.830154
#         2023-03-07  3526.161860   474.836194  1550.015314  2289.466743
#         2023-03-08  3396.568735   -10.900963  1234.965073  2051.567070
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   525.635440   -89.723425   174.901249   306.852705
#         2023-03-28   541.643659   -72.281207   169.225231   325.749660
#         2023-03-29   547.976154   -58.583322   180.188609   329.778030
#         2023-03-30   530.794590  -203.304543   170.165488   311.098635
#         2023-03-31   527.822932  -197.143964   142.172874   299.740923
#
#                             0.4          0.5          0.6          0.7  \
# item_id timestamp
# TG_A_J  2023-03-04  3014.349782  3312.825353  3631.836279  3962.654706
#         2023-03-05   180.603015   539.654848   901.427346  1287.269430
#         2023-03-06  2653.802954  3186.212817  3718.454210  4328.340109
#         2023-03-07  2921.100309  3494.863582  4099.329227  4723.865927
#         2023-03-08  2750.735726  3398.991692  4042.873254  4733.643005
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   428.666252   536.995084   646.435404   760.451198
#         2023-03-28   440.123665   547.579332   667.326516   782.979773
#         2023-03-29   444.955090   557.439860   669.830658   788.347764
#         2023-03-30   428.803774   546.263052   660.345919   791.447021
#         2023-03-31   426.836822   539.404657   650.411487   776.133884
#
#                             0.8          0.9
# item_id timestamp
# TG_A_J  2023-03-04  4371.442224  4987.538884
#         2023-03-05  1739.741426  2366.138272
#         2023-03-06  5062.691118  6197.420663
#         2023-03-07  5506.695405  6591.927269
#         2023-03-08  5543.470846  6758.502881
# ...                         ...          ...
# RD_F_J  2023-03-27   899.086454  1102.054688
#         2023-03-28   923.880175  1129.097972
#         2023-03-29   940.716902  1147.186611
#         2023-03-30   929.674680  1152.713059
#         2023-03-31   916.350911  1137.705439
#
# [1092 rows x 10 columns]

# %%
pred_df = pd.DataFrame(preds).reset_index()
pred_df
# Out:
#      item_id  timestamp         mean          0.1          0.2          0.3  \
# 0     TG_A_J 2023-03-04  3305.099072  1585.863805  2236.841469  2663.834687
# 1     TG_A_J 2023-03-05   543.990556 -1285.068602  -656.704042  -204.257119
# 2     TG_A_J 2023-03-06  3253.064348   379.547692  1392.910740  2044.830154
# 3     TG_A_J 2023-03-07  3526.161860   474.836194  1550.015314  2289.466743
# 4     TG_A_J 2023-03-08  3396.568735   -10.900963  1234.965073  2051.567070
# ...      ...        ...          ...          ...          ...          ...
# 1087  RD_F_J 2023-03-27   525.635440   -89.723425   174.901249   306.852705
# 1088  RD_F_J 2023-03-28   541.643659   -72.281207   169.225231   325.749660
# 1089  RD_F_J 2023-03-29   547.976154   -58.583322   180.188609   329.778030
# 1090  RD_F_J 2023-03-30   530.794590  -203.304543   170.165488   311.098635
# 1091  RD_F_J 2023-03-31   527.822932  -197.143964   142.172874   299.740923
#
#               0.4          0.5          0.6          0.7          0.8  \
# 0     3014.349782  3312.825353  3631.836279  3962.654706  4371.442224
# 1      180.603015   539.654848   901.427346  1287.269430  1739.741426
# 2     2653.802954  3186.212817  3718.454210  4328.340109  5062.691118
# 3     2921.100309  3494.863582  4099.329227  4723.865927  5506.695405
# 4     2750.735726  3398.991692  4042.873254  4733.643005  5543.470846
# ...           ...          ...          ...          ...          ...
# 1087   428.666252   536.995084   646.435404   760.451198   899.086454
# 1088   440.123665   547.579332   667.326516   782.979773   923.880175
# 1089   444.955090   557.439860   669.830658   788.347764   940.716902
# 1090   428.803774   546.263052   660.345919   791.447021   929.674680
# 1091   426.836822   539.404657   650.411487   776.133884   916.350911
#
#               0.9
# 0     4987.538884
# 1     2366.138272
# 2     6197.420663
# 3     6591.927269
# 4     6758.502881
# ...           ...
# 1087  1102.054688
# 1088  1129.097972
# 1089  1147.186611
# 1090  1152.713059
# 1091  1137.705439
#
# [1092 rows x 12 columns]

# %%
pred_mean = pred_df['mean']
pred_mean
# Out:
# 0       3305.099072
# 1        543.990556
# 2       3253.064348
# 3       3526.161860
# 4       3396.568735
#            ...
# 1087     525.635440
# 1088     541.643659
# 1089     547.976154
# 1090     530.794590
# 1091     527.822932
# Name: mean, Length: 1092, dtype: float64

# %%
(pred_mean<0).sum()
# Out:
# 19

# %%
pred_mean[pred_mean<0]=0

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('./sample_submission.csv')
submission
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
submission['answer']=pred_mean

# %%
submission.to_csv('./submission_231116.csv', index=False)
