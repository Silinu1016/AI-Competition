# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import LabelEncoder
from prophet import Prophet
import re
import copy

import warnings
warnings.filterwarnings(action='ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %%
drive_path = "/content/drive/MyDrive/데이터 경진대회/제주 특산물 가격 예측"
train_data_path = drive_path + "/train.csv"
test_data_path = drive_path + "/test.csv"
sample_submission_path = drive_path + "/sample_submission.csv"

# %%
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)

# %%
train_df["timestamp"] = pd.to_datetime(train_df["timestamp"])

# %%
category_list = train_df["ID"].str.replace(r'_\d{8}$', '', regex=True).unique()

# %%
def handle_data_to_prophet(df) :
  transformed_df = df[["ID", "timestamp", "price(원/kg)"]]
  transformed_df["ID"] = transformed_df["ID"].str.replace(r'_\d{8}$', '', regex=True)
  transformed_df = transformed_df.rename(columns={'timestamp': 'ds', 'price(원/kg)': 'y'})
  return transformed_df.copy()

# %%
prophet_train_data = handle_data_to_prophet(train_df)

# %%
prophet_train_data.head(5)
# Out:
#        ID         ds       y
# 0  TG_A_J 2019-01-01     0.0
# 1  TG_A_J 2019-01-02     0.0
# 2  TG_A_J 2019-01-03  1728.0
# 3  TG_A_J 2019-01-04  1408.0
# 4  TG_A_J 2019-01-05  1250.0

# %% [markdown]
# ### Prophet 하이퍼 파라미터 탐색

# %%
search_data = prophet_train_data[prophet_train_data["ID"] == "TG_A_J"].drop(columns=["ID"]).sort_values("ds").copy()

# %%
train_size = int(len(search_data) * 0.8)
search_train_data = search_data[:train_size]
# 만약 0을 제외하고 사용하려면 아래 줄 주석을 해제하세요
# search_train_data = search_train_data[search_train_data["y"] > 0]
search_test_data = search_data[train_size:]

# %%
search_train_data
# Out:
#              ds       y
# 0    2019-01-01     0.0
# 1    2019-01-02     0.0
# 2    2019-01-03  1728.0
# 3    2019-01-04  1408.0
# 4    2019-01-05  1250.0
# ...         ...     ...
# 1213 2022-04-28  5508.0
# 1214 2022-04-29  5998.0
# 1215 2022-04-30  5415.0
# 1216 2022-05-01     0.0
# 1217 2022-05-02  4891.0
#
# [1218 rows x 2 columns]

# %%
param_grid = {
    'growth': ['linear'],
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 1, 5, 10],
    'seasonality_prior_scale': [0.01, 0.1, 1, 5, 10],
    'changepoint_range': [0.8, 0.85, 0.9, 0.95],
    'yearly_seasonality': [True, False],
    'weekly_seasonality': [True, False],
    'daily_seasonality': [True, False],
    'holidays_prior_scale': [0.1, 1, 5],
}

# %%
def prophet_grid_search(num_iterations, param_grid, train_data, y):
  results = []

  for _ in range(num_iterations) :
    random_params = {
        key : random.choice(value) for key, value in param_grid.items()
    }

    current_model = Prophet(**random_params)
    current_model.fit(train_data)

    y_size = len(y)

    future = current_model.make_future_dataframe(periods=y_size)
    forecast = current_model.predict(future)
    m_predict = forecast["yhat"].values[-y_size:]

    se = np.square(m_predict - y)
    rmse = np.sqrt(np.mean(se))

    results.append((random_params, rmse))
  return results

# %%
model_per_category = {}
for category in category_list:
  search_data = prophet_train_data[prophet_train_data["ID"] == category].drop(columns=["ID"]).sort_values("ds").copy()
  train_size = int(len(search_data) * 0.8)
  search_train_data = search_data[:train_size]
  # 만약 0을 제외하고 사용하려면 아래 줄 주석을 해제하세요
  # search_train_data = search_train_data[search_train_data["y"] > 0]
  search_test_data = search_data[train_size:]
  y = search_test_data["y"].values[:]
  results = prophet_grid_search(30, param_grid, search_train_data, y)
  sorted_results = sorted(results, key=lambda x : x[1])[:5]
  model_per_category[category] = sorted_results
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/n6w8anpg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67052', 'data', 'file=/tmp/tmpseqb8u09/hgzaq0e2.json', 'init=/tmp/tmpseqb8u09/n6w8anpg.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modellz7s27w0/prophet_model-20231109135520.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/_nz_6vhx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/30qhrmzk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89405', 'data', 'file=/tmp/tmpseqb8u09/_nz_6vhx.json', 'init=/tmp/tmpseqb8u09/30qhrmzk.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modeldry0pvgu/prophet_model-20231109135521.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/zzj6s6ki.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/y9ze_vqs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88662', 'data', 'file=/tmp/tmpseqb8u09/zzj6s6ki.json', 'init=/tmp/tmpseqb8u09/y9ze_vqs.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modell3hxvgsg/prophet_model-20231109135522.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/uetwokc_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/i8ryby3v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93459', 'data', 'file=/tmp/tmpseqb8u09/uetwokc_.json', 'init=/tmp/tmpseqb8u09/i8ryby3v.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model20vo9dbj/prophet_model-20231109135523.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/asjcxzlf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/d0s46784.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26849', 'data', 'file=/tmp/tmpseqb8u09/asjcxzlf.json', 'init=/tmp/tmpseqb8u09/d0s46784.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelt11uys92/prophet_model-20231109135524.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/y9uid66q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/8pvc6jf1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9224', 'data', 'file=/tmp/tmpseqb8u09/y9uid66q.json', 'init=/tmp/tmpseqb8u09/8pvc6jf1.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model7e8y04qv/prophet_model-20231109135525.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/1p3hz1zx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/u4zjyy7g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89386', 'data', 'file=/tmp/tmpseqb8u09/1p3hz1zx.json', 'init=/tmp/tmpseqb8u09/u4zjyy7g.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model6043u8og/prophet_model-20231109135526.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/pbjua7l3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/e6v0a1pn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22180', 'data', 'file=/tmp/tmpseqb8u09/pbjua7l3.json', 'init=/tmp/tmpseqb8u09/e6v0a1pn.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model6ermfnpc/prophet_model-20231109135527.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/r4pg8n00.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/enp4or8i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5378', 'data', 'file=/tmp/tmpseqb8u09/r4pg8n00.json', 'init=/tmp/tmpseqb8u09/enp4or8i.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modela5q4t065/prophet_model-20231109135527.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/d82qr_04.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/6l1gpaae.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18245', 'data', 'file=/tmp/tmpseqb8u09/d82qr_04.json', 'init=/tmp/tmpseqb8u09/6l1gpaae.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelrsbz4k7b/prophet_model-20231109135528.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/kzuuzqgb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/07ume0wc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54178', 'data', 'file=/tmp/tmpseqb8u09/kzuuzqgb.json', 'init=/tmp/tmpseqb8u09/07ume0wc.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelkqls2vfn/prophet_model-20231109135529.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:55:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:55:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/ql6_55mp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/lduy888g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27769', 'data', 'file=/tmp/tmpseqb8u09/7faefiwq.json', 'init=/tmp/tmpseqb8u09/d8c9zm1p.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model88_vk_v3/prophet_model-20231109140427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:04:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:04:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/gk7mpajg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/wobb7be6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76102', 'data', 'file=/tmp/tmpseqb8u09/gk7mpajg.json', 'init=/tmp/tmpseqb8u09/wobb7be6.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelopw_hck3/prophet_model-20231109140427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:04:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:04:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/9wjpc7wj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/k7n1ogqj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94282', 'data', 'file=/tmp/tmpseqb8u09/9wjpc7wj.json', 'init=/tmp/tmpseqb8u09/k7n1ogqj.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model1jemb6f5/prophet_model-20231109140429.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:04:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:04:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/y5dasf8z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/i8yv5al5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66702', 'data', 'file=/tmp/tmpseqb8u09/y5dasf8z.json', 'init=/tmp/tmpseqb8u09/i8yv5al5.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelx2ad825_/prophet_model-20231109140430.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:04:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:04:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/72k99pet.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/tz0nbubs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6319', 'data', 'file=/tmp/tmpseqb8u09/72k99pet.json', 'init=/tmp/tmpseqb8u09/tz0nbubs.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelxw3nmqlt/prophet_model-20231109140431.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:04:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:04:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test_result = model_per_category["TG_A_J"]

# %%
best_params, best_rmse = min(test_result, key=lambda x: x[1])

# %%
test_model = Prophet(**best_params)
test_model.fit(search_train_data)
future = test_model.make_future_dataframe(periods=305)
forecast = test_model.predict(future)
test_model.plot(forecast)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/wdgmtr63.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/8113v2vm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67200', 'data', 'file=/tmp/tmpseqb8u09/wdgmtr63.json', 'init=/tmp/tmpseqb8u09/8113v2vm.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelcg3kyq7i/prophet_model-20231109140632.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prophet_map = {}

# %%
for category in category_list :
  category_prophet_result = model_per_category[category]
  best_params, best_rmse = min(category_prophet_result, key=lambda x: x[1])
  main_model = Prophet(
      **best_params
  )
  current_category_train_x = prophet_train_data[prophet_train_data["ID"] == category].drop(columns=["ID"]).sort_values("ds")
  prophet_map[category] = main_model.fit(current_category_train_x)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/lko9utnv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/z64a8gxs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29418', 'data', 'file=/tmp/tmpseqb8u09/lko9utnv.json', 'init=/tmp/tmpseqb8u09/z64a8gxs.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelq15t1qqx/prophet_model-20231109140643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/x1telc_9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/xp0hu9wh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56142', 'data', 'file=/tmp/tmpseqb8u09/x1telc_9.json', 'init=/tmp/tmpseqb8u09/xp0hu9wh.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model6m0xglnr/prophet_model-20231109140644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/csea2pdz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/lf1x82c_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57628', 'data', 'file=/tmp/tmpseqb8u09/csea2pdz.json', 'init=/tmp/tmpseqb8u09/lf1x82c_.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modely8uxa8yy/prophet_model-20231109140644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/4exyra3k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/btd03lp6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3159', 'data', 'file=/tmp/tmpseqb8u09/4exyra3k.json', 'init=/tmp/tmpseqb8u09/btd03lp6.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelnox8afsd/prophet_model-20231109140644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/72r5jthp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/xerzo7wu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6079', 'data', 'file=/tmp/tmpseqb8u09/72r5jthp.json', 'init=/tmp/tmpseqb8u09/xerzo7wu.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelykdzcfar/prophet_model-20231109140645.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14
json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56864', 'data', 'file=/tmp/tmpseqb8u09/62z_ya11.json', 'init=/tmp/tmpseqb8u09/8tf44aao.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model0clj5b79/prophet_model-20231109140659.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/t2zn5obl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/6f0xzzs6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14847', 'data', 'file=/tmp/tmpseqb8u09/t2zn5obl.json', 'init=/tmp/tmpseqb8u09/6f0xzzs6.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelnsh9hqj5/prophet_model-20231109140659.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/q1k3su0y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/5jj7mzng.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25240', 'data', 'file=/tmp/tmpseqb8u09/q1k3su0y.json', 'init=/tmp/tmpseqb8u09/5jj7mzng.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelqqvf2pu0/prophet_model-20231109140659.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:06:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:06:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/1lhsldt_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/ugjtx3jd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81237', 'data', 'file=/tmp/tmpseqb8u09/1lhsldt_.json', 'init=/tmp/tmpseqb8u09/ugjtx3jd.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelq05kfc0y/prophet_model-20231109140700.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:07:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:07:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/hll93w1l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/d5ca9flb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1646', 'data', 'file=/tmp/tmpseqb8u09/hll93w1l.json', 'init=/tmp/tmpseqb8u09/d5ca9flb.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelhnumv4e3/prophet_model-20231109140701.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:07:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:07:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/a7tpstt3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/2qz0y994.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65961', 'data', 'file=/tmp/tmpseqb8u09/a7tpstt3.json', 'init=/tmp/tmpseqb8u09/2qz0y994.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_modelv70srz_x/prophet_model-20231109140701.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:07:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:07:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/cd7iojn9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpseqb8u09/_1c3gxxa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88376', 'data', 'file=/tmp/tmpseqb8u09/cd7iojn9.json', 'init=/tmp/tmpseqb8u09/_1c3gxxa.json', 'output', 'file=/tmp/tmpseqb8u09/prophet_model8oh0kro9/prophet_model-20231109140702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:07:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:07:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test_df["price(원/kg)"] = 0

# %%
prophet_test_data = handle_data_to_prophet(test_df)

# %%
result_map = {}
for category in category_list :
  current_category_test_x = prophet_test_data[prophet_test_data["ID"] == category].drop(columns=["ID"])
  model = prophet_map[category]
  y = model.predict(current_category_test_x)
  result_map[category] = y["yhat"].values.tolist()

# %%
copy_result_map = copy.deepcopy(result_map)

# %%
def assign_result(row) :
  category = re.sub(r'_\d{8}$', '', row["ID"])
  result = copy_result_map[category]
  return result.pop(0)

# %%
submission = pd.read_csv(sample_submission_path)

# %%
submission.head()
# Out:
#                 ID  answer
# 0  TG_A_J_20230304       0
# 1  TG_A_J_20230305       0
# 2  TG_A_J_20230306       0
# 3  TG_A_J_20230307       0
# 4  TG_A_J_20230308       0

# %%
submission["answer"] = 0

# %%
submission["answer"] = submission.apply(assign_result, axis=1)

# %%
submission.tail()
# Out:
#                    ID      answer
# 1087  RD_F_J_20230327  366.497787
# 1088  RD_F_J_20230328  373.845092
# 1089  RD_F_J_20230329  363.888414
# 1090  RD_F_J_20230330  356.250767
# 1091  RD_F_J_20230331  350.316457

# %%
submission.loc[submission["answer"] < 0, "answer"] = 0

# %%
submission[submission["answer"] < 0]
# Out:
# Empty DataFrame
# Columns: [ID, answer]
# Index: []

# %%
submission.to_csv(drive_path + "/submission_231109_1.csv", index=False)

# %%
len(category_list)
# Out:
# 39
